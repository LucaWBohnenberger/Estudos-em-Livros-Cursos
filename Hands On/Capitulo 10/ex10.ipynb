# %%
from tensorflow import keras
Input = keras.layers.Input
Dense = keras.layers.Dense

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
input = Input(shape=[28,28])
flat = keras.layers.Flatten()(input)
hidden = Dense(300, activation="relu")(flat)
hidden2 = Dense(100, activation="relu")(hidden)
output = Dense(10, activation="softmax")(hidden2)
model = keras.Model(inputs=input, outputs=output)

# %%
# K = keras.backend

# class ExponentialLearningRate(keras.callbacks.Callback):
#     def __init__(self, factor):
#         self.factor = factor
#         self.rates = []
#         self.losses = []
#     def on_batch_end(self, batch, logs):
#         # Pega a taxa de aprendizado atual (que é um objeto tf.Variable)
#         lr = self.model.optimizer.learning_rate
        
#         # Guarda o valor numérico na sua lista
#         self.rates.append(lr.numpy())
#         self.losses.append(logs["loss"])
        
#         # Atualiza o valor da taxa de aprendizado usando o método .assign()
#         lr.assign(lr * self.factor)

# %%
# model.compile(loss="sparse_categorical_crossentropy",
#               optimizer=keras.optimizers.SGD(learning_rate=1e-3),
#               metrics=["accuracy"])
# expon_lr = ExponentialLearningRate(factor=1.005)

# %%
# history = model.fit(X_train, y_train, epochs=1,
#                     validation_split=0.2,
#                     callbacks=[expon_lr])

# %%
# import matplotlib.pyplot as plt
# plt.plot(expon_lr.rates, expon_lr.losses)
# plt.gca().set_xscale('log')
# plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
# plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
# plt.grid()
# plt.xlabel("Learning rate")
# plt.ylabel("Loss")

# %%
early_stop = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
tensorboard = keras.callbacks.TensorBoard("ex10")

# %%
model = keras.Model(inputs=input, outputs=output)
model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.SGD(0.03), metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, validation_split=0.2, callbacks=[early_stop, tensorboard], epochs=200)
# Out:
# Epoch 1/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8823 - loss: 0.4243 - val_accuracy: 0.9293 - val_loss: 0.2375
# Epoch 2/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9412 - loss: 0.2018 - val_accuracy: 0.9520 - val_loss: 0.1683
# Epoch 3/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9569 - loss: 0.1458 - val_accuracy: 0.9634 - val_loss: 0.1338
# Epoch 4/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9672 - loss: 0.1137 - val_accuracy: 0.9648 - val_loss: 0.1206
# Epoch 5/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9735 - loss: 0.0927 - val_accuracy: 0.9696 - val_loss: 0.1062
# Epoch 6/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9778 - loss: 0.0773 - val_accuracy: 0.9721 - val_loss: 0.0963
# Epoch 7/200
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9809 - loss: 0.0654 - val_accuracy: 0.9730 - val_loss: 0.0931
# Epoch 8/200
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9782 - loss: 0.0713
# [0.07134360074996948, 0.9782000184059143]
