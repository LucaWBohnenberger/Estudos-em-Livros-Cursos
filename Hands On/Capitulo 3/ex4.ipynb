# %%
import pandas as pd
import bz2
import tarfile

# %%
import tarfile

with tarfile.open("arquivo.tar.bz2", "r:bz2") as tar:
    tar.extractall(path="destino")  # extrai tudo para a pasta destino

# %%
with tarfile.open("ham.tar.bz2", "r:bz2") as tar:
    tar.extractall(path="destino")  # extrai tudo para a pasta destino
